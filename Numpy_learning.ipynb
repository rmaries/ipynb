# %% [markdown]
# # Learning numpy

# %% [markdown]
# I refer the below video to learn numpy

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('gtejJ3RCddE')

# %%
import numpy as np
a = np.array([1, 2, 3, 4])
a
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])

# %%
b = np.array([4,5,6,7])
a * b
# Out:
# array([ 4, 10, 18, 28])

# %%
a + b
# Out:
# array([ 5,  7,  9, 11])

# %%
a/b
# Out:
# array([ 0.25      ,  0.4       ,  0.5       ,  0.57142857])

# %%
np.sin(a)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 ])

# %%
# %matplotlib inline
import pylab
pylab.plot(np.sin(a))
