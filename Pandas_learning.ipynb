# %% [markdown]
# # Notebook to learn pandas using the below video

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("6ohWS7J1hVA")

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

pd.set_option("display.max_rows", 16)
LARGE_FIGSIZE = (12, 8)

# %%
#change the location to the tutorial location
# %cd ./pandas_tutorial/climate_timeseries/
# %ls
# Out:
# /home/prabhamaries/Documents/maries/ipynb/pandas_tutorial/climate_timeseries
# climate_timeseries-Part1.ipynb  climate_timeseries-Part2.ipynb  data/  sandbox/
